# %%
import sys
sys.path.append('..')
from api.api import PDTB
from constituent import Constituent
import itertools

# %%
pdtb2 = '/home/pengfei/data/pdtb_v2/all/conll/'
pdtb3 = PDTB(pdtb2)

# %% [markdown]
# ## only for one individual sentence for explicit

# %%
def get_constituents(docid, sentid, conn_index):
    """
    Args:
            docid(str)
            sentid(int)
            conn_index(list[int])
    Returns:
            [ [(token_index, text),...], ...]"""
    syntax_tree = pdtb3.get_syntax_tree(docid, sentid)
    if syntax_tree.tree == None:
        return []
    all_leaves = syntax_tree.tree.get_leaves()
    conn_indices = conn_index
    constituent_nodes = []
    if len(conn_indices) == 1:# like and or so...
        conn_node = syntax_tree.get_leaf_node_by_token_index(conn_indices[0]).up
    else:
        conn_node = syntax_tree.get_common_ancestor_by_token_indices(conn_indices)
        conn_leaves = set([all_leaves.index(syntax_tree.get_leaf_node_by_token_index(conn_index)) for conn_index in conn_indices])
        children = conn_node.get_children()
        for child in children:
            leaves = set([all_leaves.index(n) for n in child.get_leaves()])
            if list(leaves-conn_leaves)!=[]: constituent_nodes.append(list(leaves-conn_leaves))
    curr = conn_node
    while not curr.is_root():
        sibs = [ [all_leaves.index(n) for n in sib] for sib in syntax_tree.get_siblings(curr)]
        constituent_nodes.extend(sibs)
        curr = curr.up

    tokens_indices_with_text = pdtb3.get_tokens_indices_with_text(docid, sentid)
    subtree_list = [ [(o,tokens_indices_with_text[o][2]) for o in node] for node in constituent_nodes]
    return subtree_list

def merge_consti(subtree_list):
    return {(o[0][0],o[-1][0]):i for i,o in enumerate(subtree_list)}

def arg_is_contained(i, arg):
    docid = pdtb3.parse_data[i]['DocID']
    sentid = pdtb3.get_arg_sent_id(i, arg)
    conn_indices = [o[1] for o in pdtb3.get_arg_token_list(i, 'Connective')]
    subtree_list = get_constituents(docid, sentid[0], conn_indices)
    merged_consti_list = merge_consti(subtree_list)
    token_list = pdtb3.get_arg_token_list(i, arg)
    start,end = token_list[0][1], token_list[-1][1]
    # filter results
    consti_list = [k for k in merged_consti_list.keys() if k[0]>=start and k[1]<=end]
    # generate results
    results = []
    for i in range(1, len(consti_list)+1):
        for subset in itertools.combinations(consti_list, i):
            results.append(expand(subset))
    # check
    return [o[1] for o in token_list] in results

def expand(subset):
    ret = []
    for subsubset in subset:
        for i in range(subsubset[0], subsubset[1]+1):
            ret.append(i)
    return sorted(ret)

# %%
arg_is_contained(34, 'Arg1')
# pdtb3.get_arg_token_list(6, 'Arg1')
# Out:
# False

# %%
bad = 0
total =0
for i in range(1000):
    if pdtb3.parse_data[i]['Type'] == 'Explicit' and pdtb3.get_arg_sent_id(i,'Arg1')[0] == pdtb3.get_arg_sent_id(i,'Arg2')[0]:
        total+=1
        if not arg_is_contained(i, 'Arg1'):
            bad += 1
#             print(pdtb3.get_highlighted_parsetree(i, v=True))
bad/total
# Out:
# 0.1111111111111111

# %%
bad = 0
total =0
for i in range(1000):
    if pdtb3.parse_data[i]['Type'] == 'Explicit' and pdtb3.get_arg_sent_id(i,'Arg1')[0] == pdtb3.get_arg_sent_id(i,'Arg2')[0]:
        total+=1
        if not arg_is_contained(i, 'Arg2'):
            bad += 1
            print(pdtb3.get_highlighted_parsetree(i, v=True))
bad/total
# Out:
# Relation: 22,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0207,	Type: Explicit,	Sense: Expansion.Conjunction,
# Arg1_sent_id: 10	,	Arg2_sent_id: 10
#
#    /- /-Clad
#   |
#   |   /- /-in
#   |  |
#   |  |   /- /-his
#   |--|  |
#   |  |  |-- /-trademark
#   |  |  |
#   |   \-|-- /-black
#   |     |
#   |     |-- /-velvet
#   |     |
#   |      \- /-suit
#   |
#   |-- /-*COMMA*
#   |
#   |   /- /-the
#   |  |
#   |--|-- /-soft-spoken
#   |  |
#   |   \- /-clarinetist
#   |
#   |   /- /-announced
#   |  |
#   |  |      /- /-that
#   |  |     |
#   |  |     |         /- /-his
#   |  |     |        |
#   |  |     |      /-|-- /-new
#   |  |     |     |  |
#   |  |     |     |   \- /-album
#   |  |     |     |
#   |  |   /-|     |-- /-*COMMA*
#   |  |  |  |     |
#   |  |  |  |     |-- /-``
#   |  |  |  |   /-|
#   |  |  |  |  |  |   /- /-Inner
#   |  |  |  |  |  |--|
#   |--|  |  |  |  |   \- /-Voices
#   |  |  |  |  |  |
#   |  |  |   \-|  |-- /-*COMMA*
#   |  |  |     |  |
#   |  |  |     |   \- /-''
#   |  |  |     |
#   |  |  |     |   /- /-had
#   |  |  |     |  |
#   |  |  |      \-|-- /- /-just
#   |  |  |        |
#   |  |  |        |   /- /-been
#   |  |  |         \-|
#   |  |  |            \- /- /-released
#   |  |  |
#   |  |  |-- /-*COMMA*
#   |  |  |
#   |   \-|   /- /-that
#   |     |  |
#   |     |--|      /- /-his
# --|     |  |   /-|
#   |     |  |  |   \- /-family
#   |     |   \-|
#   |     |     |   /- /-was
#   |     |     |  |
#   |     |      \-|   /- /-in
#   |     |        |  |
#   |     |         \-|   /- /-the
#   |     |           |  |
#   |     |            \-|-- /-front
#   |     |              |
#   |     |               \- /-row
#   |     |
#   |     |-- /-*COMMA*
#   |     |
#   |     |-- /-and
#   |     |
#   |     |   /- /-that
#   |     |  |
#   |     |  |   /- /- /-it
#   |      \-|  |
#   |        |  |   /- /-was
#   |        |  |  |
#   |         \-|  |      /- /-his
#   |           |  |     |
#   |           |  |   /-|-- /-mother
#   |           |  |  |  |
#   |           |  |--|   \- /-'s
#   |            \-|  |
#   |              |   \- /-birthday
#   |              |
#   |              |-- /-*COMMA*
#   |              |
#   |              |   /- /-so
#   |              |  |
#   |               \-|   /- /- /-he
#   |                 |  |
#   |                  \-|   /- /-was
#   |                    |  |
#   |                     \-|   /- /-going
#   |                       |  |
#   |                        \-|      /- /-to
#   |                          |     |
#   |                          |     |   /- /-play
#   |                           \- /-|  |
#   |                                |  |   /- /-her
#   |                                |  |  |
#   |                                 \-|--|-- /-favorite
#   |                                   |  |
#   |                                   |   \- /-tune
#   |                                   |
#   |                                   |   /- /-from
#   |                                    \-|
#   |                                      |   /- /-the
#   |                                       \-|
#   |                                          \- /-record
#   |
#    \- /-.
#
# Relation: 32,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0207,	Type: Explicit,	Sense: Temporal.Asynchronous.Precedence,
# Arg1_sent_id: 17	,	Arg2_sent_id: 17
#
#       /- /-Mr.
#    /-|
#   |   \- /-Stoltzman
#   |
#   |      /- /-tied
#   |     |
#   |     |   /- /-the
#   |     |--|
#   |     |   \- /-composer
#   |   /-|
#   |  |  |-- /- /-in
#   |  |  |
#   |  |  |   /- /-by
#   |  |  |  |
#   |  |  |  |      /- /-proclaiming
#   |  |   \-|     |
#   |  |     |     |-- /- /-him
#   |  |     |     |
#   |  |     |     |-- /-``
#   |  |      \- /-|
#   |  |           |      /- /-the
#   |  |           |     |
#   |  |           |   /-|-- /-great
#   |  |           |  |  |
#   |  |           |  |   \- /-improviser
#   |  |            \-|
#   |--|              |   /- /-of
#   |  |              |  |
#   |  |               \-|   /- /-the
#   |  |                 |  |
#   |  |                  \-|-- /-18th
#   |  |                    |
#   |  |                     \- /-century
#   |  |
#   |  |-- /-*COMMA*
#   |  |
#   |  |-- /-''
#   |  |
#   |  |-- /-and
#   |  |
#   |  |-- /- /-then
#   |  |
#   |  |   /- /-built
#   |  |  |
#   |   \-|   /- /-on
# --|     |  |
#   |     |  |      /- /-the
#   |      \-|   /-|
#   |        |  |   \- /-image
#   |        |  |
#   |         \-|   /- /-by
#   |           |  |
#   |           |  |      /- /-joining
#   |           |  |     |
#   |            \-|     |   /- /-with
#   |              |     |--|
#   |              |     |  |   /- /-Mr.
#   |              |     |   \-|
#   |               \- /-|      \- /-Douglas
#   |                    |
#   |                    |   /- /-in
#   |                    |  |
#   |                    |  |      /- /-some
#   |                    |  |     |
#   |                    |  |     |-- /-Bach
#   |                     \-|   /-|
#   |                       |  |  |-- /-two-part
#   |                       |  |  |
#   |                       |  |   \- /-inventions
#   |                       |  |
#   |                       |  |-- /-*COMMA*
#   |                        \-|
#   |                          |      /- /- /-cleverly
#   |                          |     |
#   |                          |   /-|-- /-arranged
#   |                          |  |  |
#   |                          |  |  |   /- /-for
#   |                          |  |   \-|
#   |                           \-|      \- /- /-clarinet
#   |                             |
#   |                             |-- /-and
#   |                             |
#   |                             |   /- /- /-bassoon
#   |                              \-|
#   |                                |   /- /-by
#   |                                 \-|
#   |                                   |   /- /-Mr.
#   |                                    \-|
#   |                                       \- /-Douglas
#   |
#    \- /-.
#
# Relation: 52,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0207,	Type: Explicit,	Sense: Comparison.Contrast,
# Arg1_sent_id: 33	,	Arg2_sent_id: 33
#
#          /- /-Managers
#         |
#       /-|-- /-and
#      |  |
#      |   \- /-presenters
#    /-|
#   |  |   /- /-insist
#   |  |  |
#   |   \-|   /- /-that
#   |     |  |
#   |     |  |      /- /-chamber
#   |      \-|     |
#   |        |   /-|-- /-music
#   |        |  |  |
#   |        |  |   \- /-concerts
#   |         \-|
#   |           |   /- /-are
#   |           |  |
#   |            \-|   /- /-a
#   |              |  |
#   |               \-|-- /-hard
#   |                 |
#   |                  \- /-sell
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-but
#   |
# --|   /- /-can
#   |  |
#   |  |-- /- /-audiences
#   |  |
#   |  |-- /- /-really
#   |  |
#   |  |   /- /-enjoy
#   |  |  |
#   |  |  |-- /- /-them
#   |  |--|
#   |  |  |   /- /-only
#   |  |  |  |
#   |  |  |  |-- /-if
#   |  |   \-|
#   |  |     |      /- /-the
#   |  |     |   /-|
#   |  |     |  |   \- /-music
#   |  |      \-|
#   |  |        |   /- /-is
#   |  |        |  |
#   |  |         \-|   /- /-purged
#   |  |           |  |
#   |  |           |  |   /- /-of
#   |  |            \-|  |
#    \-|              |  |      /- /-threatening
#      |              |  |   /-|
#      |               \-|  |   \- /-elements
#      |                 |  |
#      |                 |  |-- /-*COMMA*
#      |                 |  |
#      |                 |  |      /- /-served
#      |                  \-|     |
#      |                    |   /-|-- /- /-up
#      |                    |  |  |
#      |                    |  |  |   /- /-in
#      |                    |  |   \-|
#      |                    |  |     |   /- /-bite-sized
#      |                     \-|      \-|
#      |                       |         \- /-morsels
#      |                       |
#      |                       |-- /-and
#      |                       |
#      |                       |   /- /-accompanied
#      |                        \-|
#      |                          |   /- /-by
#      |                           \-|
#      |                              \- /- /-visuals
#      |
#       \- /-?
#
# Relation: 72,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0208,	Type: Explicit,	Sense: Comparison.Contrast,
# Arg1_sent_id: 14	,	Arg2_sent_id: 14
#
#       /- /- /-Glasnost
#    /-|
#   |  |   /- /-may
#   |   \-|
#   |     |   /- /-be
#   |      \-|
#   |        |   /- /-partly
#   |         \-|
#   |            \- /-responsible
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-but
#   |
#   |      /- /-Soviet
#   |     |
#   |     |-- /-Foreign
#   |     |
#   |   /-|-- /-Minister
#   |  |  |
#   |  |  |-- /-Eduard
#   |  |  |
#   |  |   \- /-Shevardnadze
#   |  |
#   |  |   /- /-last
#   |  |--|
#   |--|   \- /-year
# --|  |
#   |  |   /- /-admitted
#   |  |  |
#   |  |  |-- /-*COMMA*
#   |  |  |
#   |  |  |-- /-``
#   |  |  |
#   |   \-|      /- /-The
#   |     |     |
#   |     |     |-- /-exaggerated
#   |     |   /-|
#   |     |  |  |-- /-ideological
#   |     |  |  |
#   |     |  |   \- /-approach
#   |      \-|
#   |        |      /- /-undermined
#   |        |   /-|
#   |        |  |   \- /-tolerance
#   |         \-|
#   |           |   /- /-intrinsic
#   |            \-|
#   |              |   /- /-to
#   |               \-|
#   |                  \- /- /-UNESCO
#   |
#   |-- /-.
#   |
#    \- /-''
#
# Relation: 84,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0208,	Type: Explicit,	Sense: Temporal.Synchrony,
# Arg1_sent_id: 26	,	Arg2_sent_id: 26
#
#          /- /-Free
#       /-|
#      |   \- /-markets
#      |
#      |-- /-*COMMA*
#      |
#      |   /- /-free
#    /-|--|
#   |  |   \- /-minds
#   |  |
#   |  |-- /-and
#   |  |
#   |  |   /- /-free
#   |   \-|
#   |      \- /-elections
#   |
#   |   /- /-have
#   |  |
#   |--|      /- /-an
#   |  |   /-|
#   |  |  |   \- /-appeal
#   |   \-|
#   |     |   /- /- /-that
#   |     |  |
#   |      \-|      /- /-seems
#   |        |     |
#   |         \- /-|      /- /-to
#   |              |     |
#   |               \- /-|   /- /-get
#   |                    |  |
#   |                     \-|   /- /-muddled
#   |                       |  |
#   |                        \-|      /- /-only
#   |                          |   /-|
#   |                          |  |   \- /-when
#   |                           \-|
#   |                             |      /- /-delivered
#   |                             |     |
#   |                              \- /-|   /- /-through
#   |                                   |  |
#   |                                   |  |      /- /-U.N.
# --|                                    \-|   /-|
#   |                                      |  |   \- /-organizations
#   |                                      |  |
#   |                                       \-|-- /---
#   |                                         |
#   |                                         |   /- /- /-which
#   |                                         |  |
#   |                                          \-|      /- /-of
#   |                                            |   /-|
#   |                                            |  |   \- /- /-course
#   |                                             \-|
#   |                                               |   /- /-are
#   |                                               |  |
#   |                                                \-|   /- /-made
#   |                                                  |  |
#   |                                                  |  |-- /- /-up
#   |                                                   \-|
#   |                                                     |   /- /- /-largely
#   |                                                     |  |
#   |                                                     |  |-- /-of
#   |                                                      \-|
#   |                                                        |   /- /- /-governments
#   |                                                        |  |
#   |                                                         \-|   /- /- /-that
#   |                                                           |  |
#   |                                                            \-|      /- /-fear
#   |                                                              |     |
#   |                                                              |     |   /- /-these
#   |                                                               \- /-|--|
#   |                                                                    |   \- /-principles
#   |                                                                    |
#   |                                                                    |   /- /-at
#   |                                                                     \-|
#   |                                                                        \- /- /-home
#   |
#    \- /-.
#
# Relation: 106,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0209,	Type: Explicit,	Sense: Temporal.Asynchronous.Precedence,
# Arg1_sent_id: 18	,	Arg2_sent_id: 18
#
#       /- /-The
#      |
#    /-|-- /-sterilizing
#   |  |
#   |   \- /-gene
#   |
#   |   /- /-is
#   |  |
#   |  |   /- /-expressed
#   |--|  |
#   |  |  |-- /- /-just
#   |  |  |
#   |   \-|   /- /-before
#   |     |  |
#   |     |  |         /- /-the
#   |     |  |      /-|
#   |     |  |     |   \- /-pollen
#   |      \-|   /-|
#   |        |  |  |   /- /-is
#   |        |  |   \-|
#   |        |  |     |   /- /-about
#   |        |  |      \-|
#   |        |  |        |      /- /-to
#   |         \-|         \- /-|
#   |           |               \- /- /-develop
# --|           |
#   |           |-- /-and
#   |           |
#   |           |   /- /- /-it
#   |           |  |
#   |            \-|   /- /-deactivates
#   |              |  |
#   |               \-|      /- /-the
#   |                 |   /-|
#   |                 |  |   \- /-anthers
#   |                  \-|
#   |                    |   /- /-of
#   |                    |  |
#   |                     \-|      /- /-every
#   |                       |   /-|
#   |                       |  |   \- /-flower
#   |                        \-|
#   |                          |   /- /-in
#   |                           \-|
#   |                             |   /- /-the
#   |                              \-|
#   |                                 \- /-plant
#   |
#    \- /-.
#
# Relation: 124,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0209,	Type: Explicit,	Sense: Contingency.Cause.Reason,
# Arg1_sent_id: 38	,	Arg2_sent_id: 38
#
#    /- /- /-That
#   |
#   |   /- /-'s
#   |  |
#   |  |   /- /-because
#   |  |  |
#   |  |  |   /- /- /-pollination
#   |--|  |  |
#   |  |  |  |-- /-*COMMA*
#   |  |  |  |
#   |  |  |  |   /- /-while
#   |  |  |  |  |
#   |   \-|  |  |      /- /-easy
#   |     |  |--|   /-|
#   |     |  |  |  |  |   /- /-in
#   |     |  |  |  |   \-|
#   |     |  |   \-|      \- /- /-corn
#   |     |  |     |
#   |     |  |     |   /- /-because
#   |     |  |     |  |
#   |     |  |      \-|      /- /-the
#   |      \-|        |   /-|
#   |        |        |  |   \- /-carrier
#   |        |         \-|
#   |        |           |   /- /-is
#   |        |            \-|
#   |        |               \- /- /-wind
#   |        |
# --|        |-- /-*COMMA*
#   |        |
#   |        |      /- /-is
#   |        |   /-|
#   |        |  |  |   /- /-more
#   |        |  |   \-|
#   |        |  |      \- /-complex
#   |        |  |
#   |         \-|-- /-and
#   |           |
#   |           |   /- /-involves
#   |           |  |
#   |           |  |-- /- /-insects
#   |            \-|
#   |              |   /- /-as
#   |              |  |
#   |               \-|   /- /- /-carriers
#   |                 |  |
#   |                  \-|   /- /-in
#   |                    |  |
#   |                     \-|   /- /- /-crops
#   |                       |  |
#   |                        \-|   /- /-such
#   |                          |  |
#   |                           \-|-- /-as
#   |                             |
#   |                              \- /- /-cotton
#   |
#    \- /-.
#
# Relation: 188,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0214,	Type: Explicit,	Sense: Temporal.Asynchronous,
# Arg1_sent_id: 44	,	Arg2_sent_id: 44
#
#       /- /-These
#    /-|
#   |   \- /-days
#   |
#   |-- /- /-he
#   |
#   |   /- /-hustles
#   |  |
#   |  |   /- /-to
#   |  |  |
#   |  |--|      /- /-house-painting
#   |  |  |   /-|
#   |  |  |  |   \- /-jobs
#   |  |   \-|
#   |  |     |   /- /-in
#   |--|     |  |
#   |  |      \-|   /- /-his
#   |  |        |  |
# --|  |         \-|-- /-Chevy
#   |  |           |
#   |  |            \- /-pickup
#   |  |
#   |  |   /- /-before
#   |  |  |
#   |  |  |-- /-and
#   |   \-|
#   |     |-- /-after
#   |     |
#   |     |   /- /- /-training
#   |      \-|
#   |        |   /- /-with
#   |         \-|
#   |           |   /- /-the
#   |            \-|
#   |               \- /-Tropics
#   |
#    \- /-.
#
# Relation: 362,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0239,	Type: Explicit,	Sense: Contingency.Cause.Reason,
# Arg1_sent_id: 3	,	Arg2_sent_id: 3
#
#    /- /-But
#   |
#   |   /- /-as
#   |  |
#   |  |      /- /-the
#   |  |   /-|
#   |--|  |   \- /-French
#   |  |  |
#   |  |  |   /- /-embody
#   |  |  |  |
#   |   \-|  |      /- /-a
#   |     |  |     |
#   |     |  |   /-|-- /-Zen-like
#   |     |  |  |  |
#   |     |  |--|   \- /-state
#   |      \-|  |
#   |        |  |   /- /-of
#   |        |   \-|
#   |        |      \- /- /-blase
#   |        |
#   |        |   /- /- /-when
#   |        |  |
#   |         \-|   /- /- /-it
#   |           |  |
#   |            \-|   /- /-comes
#   |              |  |
#   |               \-|   /- /-to
#   |                 |  |
#   |                 |  |   /- /- /-athletics
#   |                  \-|  |
#   |                    |  |   /- /--LRB-
#   |                    |  |  |
#   |                    |  |  |      /- /-try
# --|                     \-|  |     |
#   |                       |  |-- /-|   /- /-finding
#   |                       |  |     |  |
#   |                       |  |     |  |      /- /-a
#   |                       |  |      \-|     |
#   |                        \-|        |   /-|-- /-Nautilus
#   |                          |        |  |  |
#   |                          |         \-|   \- /-machine
#   |                          |           |
#   |                          |           |   /- /-in
#   |                          |            \-|
#   |                          |               \- /- /-Paris
#   |                          |
#   |                           \- /--RRB-
#   |
#   |-- /-*COMMA*
#   |
#   |   /- /-my
#   |  |
#   |--|-- /-fellow
#   |  |
#   |   \- /-conventioners
#   |
#   |   /- /-were
#   |--|
#   |  |   /- /-having
#   |   \-|
#   |     |   /- /- /-none
#   |      \-|
#   |        |   /- /-of
#   |         \-|
#   |            \- /- /-it
#   |
#    \- /-.
#
# Relation: 363,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0239,	Type: Explicit,	Sense: Contingency.Condition,
# Arg1_sent_id: 3	,	Arg2_sent_id: 3
#
#    /- /-But
#   |
#   |   /- /-as
#   |  |
#   |  |      /- /-the
#   |  |   /-|
#   |--|  |   \- /-French
#   |  |  |
#   |  |  |   /- /-embody
#   |  |  |  |
#   |   \-|  |      /- /-a
#   |     |  |     |
#   |     |  |   /-|-- /-Zen-like
#   |     |  |  |  |
#   |     |  |--|   \- /-state
#   |      \-|  |
#   |        |  |   /- /-of
#   |        |   \-|
#   |        |      \- /- /-blase
#   |        |
#   |        |   /- /- /-when
#   |        |  |
#   |         \-|   /- /- /-it
#   |           |  |
#   |            \-|   /- /-comes
#   |              |  |
#   |               \-|   /- /-to
#   |                 |  |
#   |                 |  |   /- /- /-athletics
#   |                  \-|  |
#   |                    |  |   /- /--LRB-
#   |                    |  |  |
#   |                    |  |  |      /- /-try
# --|                     \-|  |     |
#   |                       |  |-- /-|   /- /-finding
#   |                       |  |     |  |
#   |                       |  |     |  |      /- /-a
#   |                       |  |      \-|     |
#   |                        \-|        |   /-|-- /-Nautilus
#   |                          |        |  |  |
#   |                          |         \-|   \- /-machine
#   |                          |           |
#   |                          |           |   /- /-in
#   |                          |            \-|
#   |                          |               \- /- /-Paris
#   |                          |
#   |                           \- /--RRB-
#   |
#   |-- /-*COMMA*
#   |
#   |   /- /-my
#   |  |
#   |--|-- /-fellow
#   |  |
#   |   \- /-conventioners
#   |
#   |   /- /-were
#   |--|
#   |  |   /- /-having
#   |   \-|
#   |     |   /- /- /-none
#   |      \-|
#   |        |   /- /-of
#   |         \-|
#   |            \- /- /-it
#   |
#    \- /-.
#
# Relation: 446,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0242,	Type: Explicit,	Sense: Comparison.Contrast,
# Arg1_sent_id: 12	,	Arg2_sent_id: 12
#
#          /- /-Oleg
#         |
#       /-|-- /-A.
#      |  |
#      |   \- /-Grinevsky
#      |
#      |-- /-*COMMA*
#      |
#      |      /- /-the
#      |     |
#      |     |-- /-chief
#      |   /-|
#      |  |  |-- /-Soviet
#    /-|  |  |
#   |  |--|   \- /-negotiator
#   |  |  |
#   |  |  |   /- /-in
#   |  |  |  |
#   |  |   \-|   /- /-the
#   |  |     |  |
#   |  |      \-|-- /-conventional-arms
#   |  |        |
#   |  |         \- /-talks
#   |  |
#   |   \- /-*COMMA*
#   |
#   |   /- /-argued
#   |  |
#   |--|   /- /-that
#   |  |  |
#   |   \-|   /- /- /-this
#   |     |  |
#   |      \-|   /- /-would
#   |        |  |
#   |         \-|   /- /-mean
#   |           |  |
#   |           |  |         /- /-the
#   |            \-|      /-|
#   |              |     |   \- /-Soviets
#   |              |     |
#   |              |     |   /- /-would
#   |               \- /-|  |
#   |                    |  |   /- /-have
#   |                    |  |  |
#   |                    |  |  |      /- /-to
#   |                     \-|  |     |
#   |                       |  |-- /-|   /- /-destroy
#   |                       |  |     |  |
# --|                       |  |      \-|      /- /-some
#   |                       |  |        |   /-|
#   |                        \-|         \-|   \- /-1*COMMA*800
#   |                          |           |
#   |                          |            \- /-tanks
#   |                          |
#   |                          |-- /-*COMMA*
#   |                          |
#   |                          |   /- /-while
#   |                          |  |
#   |                           \-|      /- /-the
#   |                             |   /-|
#   |                             |  |   \- /-U.S.
#   |                              \-|
#   |                                |   /- /-would
#   |                                |  |
#   |                                 \-|   /- /-lose
#   |                                   |  |
#   |                                   |  |-- /- /-none
#   |                                    \-|
#   |                                      |   /- /-because
#   |                                      |  |
#   |                                       \-|   /- /- /-it
#   |                                         |  |
#   |                                          \-|   /- /-has
#   |                                            |  |
#   |                                            |  |      /- /-no
#   |                                             \-|     |
#   |                                               |   /-|-- /-light
#   |                                               |  |  |
#   |                                                \-|   \- /-tanks
#   |                                                  |
#   |                                                  |   /- /-in
#   |                                                   \-|
#   |                                                      \- /- /-Europe
#   |
#    \- /-.
#
# Relation: 494,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0247,	Type: Explicit,	Sense: Expansion.Conjunction,
# Arg1_sent_id: 11	,	Arg2_sent_id: 11
#
#             /- /-Mr.
#          /-|
#         |   \- /-Agnelli
#         |
#       /-|-- /-and
#      |  |
#      |  |   /- /-the
#      |  |  |
#      |   \-|-- /-Aga
#      |     |
#    /-|      \- /-Khan
#   |  |
#   |  |-- /- /-also
#   |  |
#   |  |   /- /-have
#   |  |  |
#   |   \-|   /- /-some
#   |     |  |
#   |      \-|-- /-business
#   |        |
#   |         \- /-ties
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-and
#   |
#   |         /- /-a
#   |      /-|
#   |     |   \- /-spokesman
#   |   /-|
#   |  |  |   /- /-for
#   |  |  |  |
#   |  |   \-|   /- /-the
#   |  |     |  |
#   |  |      \-|-- /-Agnelli
#   |--|        |
#   |  |         \- /-company
# --|  |
#   |  |   /- /-did
#   |  |  |
#   |  |  |-- /-n't
#   |   \-|
#   |     |   /- /-rule
#   |     |  |
#   |      \-|   /- /-out
#   |        |  |
#   |         \-|   /- /-that
#   |           |  |
#   |           |  |      /- /-the
#   |            \-|     |
#   |              |   /-|-- /-current
#   |              |  |  |
#   |               \-|   \- /-agreement
#   |                 |
#   |                 |   /- /-could
#   |                  \-|
#   |                    |   /- /-lead
#   |                     \-|
#   |                       |   /- /-to
#   |                        \-|
#   |                          |   /- /-further
#   |                           \-|
#   |                              \- /-collaboration
#   |
#    \- /-.
#
# Relation: 516,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0250,	Type: Explicit,	Sense: Comparison.Contrast,
# Arg1_sent_id: 21	,	Arg2_sent_id: 21
#
#          /- /-Mr.
#       /-|
#      |   \- /-Kennedy
#      |
#    /-|   /- /-suggested
#   |  |  |
#   |  |  |      /- /- /-Democrats
#   |   \-|     |
#   |     |     |   /- /-``
#   |     |     |  |
#   |      \- /-|  |-- /-yielded
#   |           |  |
#   |           |  |   /- /-a
#   |           |  |  |
#   |           |  |--|-- /-great
#   |            \-|  |
#   |              |   \- /-deal
#   |              |
#   |              |-- /-''
#   |              |
#   |              |   /- /-on
#   |              |  |
#   |               \-|      /- /-the
#   |                 |   /-|
#   |                 |  |   \- /-size
#   |                  \-|
#   |                    |   /- /-of
#   |                     \-|
#   |                       |   /- /-the
#   |                        \-|
#   |                           \- /-increase
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-but
#   |
#   |   /- /- /-he
#   |  |
#   |  |   /- /-cited
#   |--|  |
#   |  |  |   /- /- /-concessions
# --|  |  |  |
#   |   \-|  |   /- /-from
#   |     |  |  |
#   |     |  |--|   /- /-the
#   |     |  |  |  |
#   |     |  |   \-|-- /-White
#   |      \-|     |
#   |        |      \- /-House
#   |        |
#   |        |   /- /-on
#   |        |  |
#   |        |  |      /- /-the
#   |        |  |     |
#   |         \-|   /-|-- /-training
#   |           |  |  |
#   |           |  |   \- /-wage
#   |           |  |
#   |            \-|-- /-*COMMA*
#   |              |
#   |              |   /- /- /-which
#   |              |  |
#   |               \-|   /- /- /-he
#   |                 |  |
#   |                  \-|   /- /-said
#   |                    |  |
#   |                     \-|         /- /-make
#   |                       |        |
#   |                        \- /- /-|   /- /- /-it
#   |                                |  |
#   |                                 \-|-- /-``
#   |                                   |
#   |                                   |   /- /-less
#   |                                    \-|
#   |                                       \- /-harsh
#   |
#   |-- /-.
#   |
#    \- /-''
#
# Relation: 536,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0254,	Type: Explicit,	Sense: Comparison.Contrast,
# Arg1_sent_id: 0	,	Arg2_sent_id: 0
#
#             /- /-The
#            |
#          /-|-- /-government
#         |  |
#         |   \- /-'s
#         |
#       /-|-- /-primary
#      |  |
#      |  |-- /-economic-forecasting
#      |  |
#      |   \- /-gauge
#    /-|
#   |  |   /- /-rose
#   |  |  |
#   |  |  |   /- /-a
#   |  |  |  |
#   |  |  |  |-- /-slight
#   |   \-|--|
#   |     |  |-- /-0.2
#   |     |  |
#   |     |   \- /-%
#   |     |
#   |     |   /- /-in
#   |      \-|
#   |         \- /- /-September
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-but
#   |
#   |   /- /- /-economists
#   |  |
#   |--|   /- /-said
#   |  |  |
#   |  |  |         /- /-the
#   |   \-|      /-|
#   |     |     |   \- /-report
#   |     |     |
# --|      \- /-|   /- /-offered
#   |           |  |
#   |           |  |      /- /-little
#   |            \-|     |
#   |              |   /-|-- /-new
#   |              |  |  |
#   |              |  |   \- /-information
#   |               \-|
#   |                 |   /- /-on
#   |                 |  |
#   |                 |  |      /- /-the
#   |                  \-|   /-|
#   |                    |  |   \- /-degree
#   |                    |  |
#   |                     \-|      /- /-to
#   |                       |   /-|
#   |                       |  |   \- /- /-which
#   |                       |  |
#   |                        \-|      /- /-the
#   |                          |     |
#   |                          |   /-|-- /-U.S.
#   |                          |  |  |
#   |                           \-|   \- /-economy
#   |                             |
#   |                             |   /- /-is
#   |                              \-|
#   |                                 \- /- /-slowing
#   |
#    \- /-.
#
# Relation: 639,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0259,	Type: Explicit,	Sense: Comparison.Concession,
# Arg1_sent_id: 15	,	Arg2_sent_id: 15
#
#       /- /- /-He
#      |
#    /-|   /- /-said
#   |  |  |
#   |   \-|      /- /- /-it
#   |     |     |
#   |     |     |   /- /-has
#   |      \- /-|  |
#   |           |  |-- /-n't
#   |           |  |
#   |            \-|-- /- /-yet
#   |              |
#   |              |   /- /-been
#   |              |  |
#   |               \-|   /- /-determined
#   |                 |  |
#   |                  \-|   /- /- /-how
#   |                    |  |
#   |                     \-|      /- /-the
#   |                       |   /-|
#   |                       |  |   \- /-RTC
#   |                        \-|
#   |                          |   /- /-will
#   |                           \-|
#   |                             |   /- /-raise
#   |                              \-|
#   |                                |   /- /-the
#   |                                 \-|
#   |                                    \- /-cash
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-but
#   |
#   |      /- /-the
#   |   /-|
#   |  |   \- /-administration
#   |  |
#   |  |   /- /-does
#   |  |  |
#   |--|  |-- /-n't
#   |  |  |
#   |  |  |   /- /-want
#   |  |  |  |
#   |  |  |  |   /- /- /-it
#   |   \-|  |  |
#   |     |  |--|   /- /-to
#   |     |  |  |  |
#   |     |  |   \-|   /- /-be
#   |     |  |     |  |
#   |     |  |      \-|   /- /-included
#   |     |  |        |  |
#   |     |  |         \-|   /- /-on
#   |      \-|           |  |
# --|        |            \-|   /- /-the
#   |        |              |  |
#   |        |               \-|-- /-federal
#   |        |                 |
#   |        |                  \- /-budget
#   |        |
#   |        |-- /-*COMMA*
#   |        |
#   |        |   /- /-because
#   |        |  |
#   |         \-|   /- /- /-it
#   |           |  |
#   |           |  |   /- /-would
#   |            \-|  |
#   |              |  |   /- /-``
#   |              |  |  |
#   |               \-|  |-- /-distort
#   |                 |  |
#   |                 |  |-- /-''
#   |                 |  |
#   |                 |  |   /- /-the
#   |                  \-|  |
#   |                    |--|-- /-budget
#   |                    |  |
#   |                    |   \- /-process
#   |                    |
#   |                    |   /- /-by
#   |                    |  |
#   |                    |  |      /- /-requiring
#   |                     \-|     |
#   |                       |     |   /- /-either
#   |                       |     |  |
#   |                        \- /-|  |   /- /- /-exemptions
#   |                             |  |--|
#   |                             |  |  |   /- /-from
#   |                             |  |   \-|
#   |                              \-|      \- /- /-Gramm-Rudman
#   |                                |
#   |                                |-- /-or
#   |                                |
#   |                                |      /- /-big
#   |                                |   /-|
#   |                                |  |   \- /-increases
#   |                                 \-|
#   |                                   |   /- /-in
#   |                                   |  |
#   |                                    \-|   /- /-the
#   |                                      |  |
#   |                                       \-|-- /-budget
#   |                                         |
#   |                                          \- /-deficit
#   |
#    \- /-.
#
# Relation: 640,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0259,	Type: Explicit,	Sense: Contingency.Cause.Reason,
# Arg1_sent_id: 15	,	Arg2_sent_id: 15
#
#       /- /- /-He
#      |
#    /-|   /- /-said
#   |  |  |
#   |   \-|      /- /- /-it
#   |     |     |
#   |     |     |   /- /-has
#   |      \- /-|  |
#   |           |  |-- /-n't
#   |           |  |
#   |            \-|-- /- /-yet
#   |              |
#   |              |   /- /-been
#   |              |  |
#   |               \-|   /- /-determined
#   |                 |  |
#   |                  \-|   /- /- /-how
#   |                    |  |
#   |                     \-|      /- /-the
#   |                       |   /-|
#   |                       |  |   \- /-RTC
#   |                        \-|
#   |                          |   /- /-will
#   |                           \-|
#   |                             |   /- /-raise
#   |                              \-|
#   |                                |   /- /-the
#   |                                 \-|
#   |                                    \- /-cash
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-but
#   |
#   |      /- /-the
#   |   /-|
#   |  |   \- /-administration
#   |  |
#   |  |   /- /-does
#   |  |  |
#   |--|  |-- /-n't
#   |  |  |
#   |  |  |   /- /-want
#   |  |  |  |
#   |  |  |  |   /- /- /-it
#   |   \-|  |  |
#   |     |  |--|   /- /-to
#   |     |  |  |  |
#   |     |  |   \-|   /- /-be
#   |     |  |     |  |
#   |     |  |      \-|   /- /-included
#   |     |  |        |  |
#   |     |  |         \-|   /- /-on
#   |      \-|           |  |
# --|        |            \-|   /- /-the
#   |        |              |  |
#   |        |               \-|-- /-federal
#   |        |                 |
#   |        |                  \- /-budget
#   |        |
#   |        |-- /-*COMMA*
#   |        |
#   |        |   /- /-because
#   |        |  |
#   |         \-|   /- /- /-it
#   |           |  |
#   |           |  |   /- /-would
#   |            \-|  |
#   |              |  |   /- /-``
#   |              |  |  |
#   |               \-|  |-- /-distort
#   |                 |  |
#   |                 |  |-- /-''
#   |                 |  |
#   |                 |  |   /- /-the
#   |                  \-|  |
#   |                    |--|-- /-budget
#   |                    |  |
#   |                    |   \- /-process
#   |                    |
#   |                    |   /- /-by
#   |                    |  |
#   |                    |  |      /- /-requiring
#   |                     \-|     |
#   |                       |     |   /- /-either
#   |                       |     |  |
#   |                        \- /-|  |   /- /- /-exemptions
#   |                             |  |--|
#   |                             |  |  |   /- /-from
#   |                             |  |   \-|
#   |                              \-|      \- /- /-Gramm-Rudman
#   |                                |
#   |                                |-- /-or
#   |                                |
#   |                                |      /- /-big
#   |                                |   /-|
#   |                                |  |   \- /-increases
#   |                                 \-|
#   |                                   |   /- /-in
#   |                                   |  |
#   |                                    \-|   /- /-the
#   |                                      |  |
#   |                                       \-|-- /-budget
#   |                                         |
#   |                                          \- /-deficit
#   |
#    \- /-.
#
# Relation: 716,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0267,	Type: Explicit,	Sense: Temporal.Asynchronous.Succession,
# Arg1_sent_id: 33	,	Arg2_sent_id: 33
# None
#
# Relation: 726,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0267,	Type: Explicit,	Sense: Temporal.Asynchronous.Succession,
# Arg1_sent_id: 41	,	Arg2_sent_id: 41
#
#    /- /-``
#   |
#   |   /- /- /-What
#   |  |
#   |--|   /- /-about
#   |  |  |
#   |   \-|      /- /-those
#   |     |   /-|
#   |     |  |   \- /-institutions
#   |      \-|
#   |        |   /- /- /-that
#   |        |  |
#   |         \-|      /- /-are
#   |           |     |
#   |            \- /-|   /- /-supposed
#   |                 |  |
#   |                  \-|      /- /-to
#   |                    |     |
#   |                     \- /-|   /- /-be
#   |                          |  |
#   |                           \-|      /- /-the
#   |                             |   /-|
#   |                             |  |   \- /-bedrock
#   |                              \-|
#   |                                |   /- /-of
#   |                                 \-|
#   |                                    \- /- /-society
#   |
#   |-- /-*COMMA*
#   |
#   |      /- /-the
#   |   /-|
#   |  |   \- /-banks
#   |  |
#   |--|-- /-and
#   |  |
#   |  |   /- /-the
#   |  |  |
#   |   \-|-- /-bar
#   |     |
#   |      \- /-association
#   |
#   |-- /-...
# --|
#   |-- /-?
#   |
#   |-- /-''
#   |
#   |-- /- /-wrote
#   |
#   |         /- /-a
#   |      /-|
#   |     |   \- /-columnist
#   |   /-|
#   |  |  |   /- /-for
#   |  |   \-|
#   |  |     |   /- /-the
#   |  |      \-|
#   |  |         \- /-Tribune-Democrat
#   |--|
#   |  |-- /-*COMMA*
#   |  |
#   |  |      /- /-a
#   |  |   /-|
#   |  |  |   \- /-newspaper
#   |   \-|
#   |     |   /- /-in
#   |      \-|
#   |        |   /- /-nearby
#   |         \-|
#   |            \- /-Johnstown
#   |
#   |-- /-*COMMA*
#   |
#   |   /- /- /-shortly
#   |  |
#   |  |-- /-after
#   |--|
#   |  |      /- /-the
#   |  |   /-|
#   |  |  |   \- /-scandal
#   |   \-|
#   |     |   /- /-became
#   |      \-|
#   |         \- /- /-public
#   |
#    \- /-.
#
# Relation: 738,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0267,	Type: Explicit,	Sense: Temporal.Asynchronous.Succession,
# Arg1_sent_id: 51	,	Arg2_sent_id: 51
#
#          /- /-Mr.
#       /-|
#      |   \- /-Green
#    /-|
#   |  |   /- /-thought
#   |   \-|
#   |     |   /- /- /-little
#   |      \-|
#   |        |   /- /-of
#   |         \-|
#   |            \- /- /-it
#   |
#   |-- /-*COMMA*
#   |
#   |-- /- /-he
#   |
#   |   /- /-told
#   |  |
#   |  |   /- /-the
#   |  |  |
#   |  |--|-- /-grand
#   |  |  |
#   |--|   \- /-jury
#   |  |
#   |  |-- /-*COMMA*
#   |  |
#   |  |   /- /-until
#   |  |  |
#   |  |  |      /- /-the
#   |   \-|   /-|
# --|     |  |   \- /-judge
#   |     |  |
#   |     |  |   /- /-walked
#   |      \-|  |
#   |        |  |-- /- /-up
#   |        |  |
#   |        |  |   /- /-to
#   |         \-|--|
#   |           |   \- /- /-him
#   |           |
#   |           |   /- /-after
#   |           |  |
#   |            \-|      /- /-the
#   |              |   /-|
#   |              |  |   \- /-courtroom
#   |               \-|
#   |                 |   /- /-had
#   |                 |  |
#   |                  \-|   /- /- /-cleared
#   |                    |  |
#   |                     \-|-- /-and
#   |                       |
#   |                       |   /- /-suggested
#   |                        \-|
#   |                          |   /- /-a
#   |                           \-|
#   |                              \- /-kickback
#   |
#    \- /-.
#
# Relation: 743,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0267,	Type: Explicit,	Sense: Expansion.Conjunction,
# Arg1_sent_id: 58	,	Arg2_sent_id: 58
#
#    /- /-``
#   |
#   |      /- /- /-I
#   |     |
#   |   /-|   /- /-do
#   |  |  |  |
#   |  |   \-|-- /-n't
#   |  |     |
#   |  |     |   /- /-have
#   |  |      \-|
#   |  |        |   /- /- /-anything
#   |  |         \-|
#   |  |           |      /- /- /-much
#   |  |            \- /-|
#   |--|                 |   /- /-to
#   |  |                  \-|
#   |  |                     \- /- /-say
#   |  |
#   |  |-- /-*COMMA*
#   |  |
#   |  |-- /-and
#   |  |
#   |  |   /- /- /-I
#   |  |  |
#   |   \-|   /- /-think
#   |     |  |
#   |      \-|      /- /- /-that
#   |        |     |
#   |         \- /-|   /- /-'s
#   |              |  |
#   |               \-|   /- /- /-what
#   |                 |  |
#   |                  \-|   /- /- /-you
#   |                    |  |
#   |                     \-|   /- /-'re
#   |                       |  |
#   |                        \-|   /- /-going
# --|                          |  |
#   |                           \-|      /- /-to
#   |                             |     |
#   |                              \- /-|   /- /-find
#   |                                   |  |
#   |                                    \-|   /- /-from
#   |                                      |  |
#   |                                       \-|      /- /-everyone
#   |                                         |   /-|
#   |                                         |  |   \- /-else
#   |                                          \-|
#   |                                            |      /- /- /-you
#   |                                             \- /-|
#   |                                                  |   /- /-talk
#   |                                                   \-|
#   |                                                     |   /- /-to
#   |                                                      \-|
#   |                                                        |   /- /-up
#   |                                                         \-|
#   |                                                            \- /-here
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-''
#   |
#   |-- /- /-says
#   |
#   |   /- /-local
#   |  |
#   |  |-- /-attorney
#   |  |
#   |--|-- /-Edward
#   |  |
#   |  |-- /-F.
#   |  |
#   |   \- /-Peduzzi
#   |
#    \- /-.
#
# Relation: 798,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0270,	Type: Explicit,	Sense: Expansion.Conjunction,
# Arg1_sent_id: 1	,	Arg2_sent_id: 1
#
#       /- /- /-Shareholders
#      |
#      |   /- /-of
#    /-|  |
#   |  |  |   /- /-the
#   |  |  |  |
#   |   \-|  |   /- /-Santa
#   |     |  |  |
#   |     |  |  |-- /-Ana
#   |     |  |  |
#   |     |  |--|-- /-*COMMA*
#   |      \-|  |
#   |        |  |-- /-Calif.
#   |        |  |
#   |        |   \- /-*COMMA*
#   |        |
#   |        |-- /-title-insurance
#   |        |
#   |         \- /-company
#   |
#   |   /- /-approved
#   |  |
#   |  |      /- /-the
#   |  |   /-|
#   |--|  |   \- /-creation
#   |  |  |
#   |  |  |   /- /-of
#   |  |  |  |
#   |   \-|  |      /- /-this
#   |     |  |     |
#   |     |  |   /-|-- /-second
#   |     |  |  |  |
#   |     |  |  |   \- /-class
#   |      \-|  |
#   |        |  |   /- /-of
#   |        |  |--|
#   |        |  |   \- /- /-stock
#   |        |  |
#   |        |  |-- /-*COMMA*
#   |        |  |
#   |        |  |      /- /- /-which
#   |         \-|     |
#   |           |   /-|      /- /-will
#   |           |  |  |     |
#   |           |  |   \- /-|   /- /-be
# --|           |  |        |  |
#   |           |  |         \-|   /- /-traded
#   |           |  |           |  |
#   |           |  |            \-|   /- /-on
#   |           |  |              |  |
#   |           |  |               \-|   /- /-the
#   |           |  |                 |  |
#   |            \-|                 |  |-- /-national
#   |              |                  \-|
#   |              |                    |-- /-over-the-counter
#   |              |                    |
#   |              |                     \- /-market
#   |              |
#   |              |-- /-and
#   |              |
#   |              |   /- /- /-which
#   |              |  |
#   |               \-|      /- /-the
#   |                 |   /-|
#   |                 |  |   \- /-company
#   |                  \-|
#   |                    |   /- /-said
#   |                    |  |
#   |                     \-|      /- /-would
#   |                       |     |
#   |                        \- /-|   /- /-be
#   |                             |  |
#   |                              \-|   /- /-used
#   |                                |  |
#   |                                 \-|   /- /-for
#   |                                   |  |
#   |                                    \-|   /- /- /-acquisitions
#   |                                      |  |
#   |                                      |  |-- /-and
#   |                                       \-|
#   |                                         |   /- /-other
#   |                                         |  |
#   |                                         |  |-- /-general
#   |                                          \-|
#   |                                            |-- /-corporate
#   |                                            |
#   |                                             \- /-purposes
#   |
#    \- /-.
#
# Relation: 866,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0274,	Type: Explicit,	Sense: Comparison.Concession,
# Arg1_sent_id: 19	,	Arg2_sent_id: 19
#
#       /- /-While
#      |
#      |   /- /- /-they
#    /-|  |
#   |  |  |   /- /-are
#   |  |  |  |
#   |  |  |  |-- /-n't
#   |   \-|  |
#   |     |  |   /- /-backed
#   |     |  |  |
#   |     |  |  |   /- /-by
#   |     |  |  |  |
#   |      \-|  |  |      /- /-the
#   |        |  |  |     |
#   |        |  |  |     |-- /-full
#   |        |  |--|     |
#   |        |  |  |   /-|-- /-faith
#   |        |  |  |  |  |
#   |        |  |  |  |  |-- /-and
#   |        |  |  |  |  |
#   |        |  |   \-|   \- /-credit
#   |         \-|     |
#   |           |     |   /- /-of
#   |           |     |  |
#   |           |      \-|   /- /-the
#   |           |        |  |
#   |           |         \-|-- /-U.S.
#   |           |           |
#   |           |            \- /-government
#   |           |
#   |           |-- /-*COMMA*
#   |           |
#   |           |   /- /-as
#   |           |  |
# --|            \-|      /- /-Treasury
#   |              |   /-|
#   |               \-|   \- /-bonds
#   |                 |
#   |                  \- /- /-are
#   |
#   |-- /-*COMMA*
#   |
#   |-- /- /-it
#   |
#   |   /- /-is
#   |  |
#   |--|   /- /- /-widely
#   |  |  |
#   |  |  |-- /-assumed
#   |   \-|
#   |     |   /- /-that
#   |     |  |
#   |      \-|      /- /-the
#   |        |   /-|
#   |        |  |   \- /-government
#   |         \-|
#   |           |   /- /-would
#   |           |  |
#   |            \-|   /- /-support
#   |              |  |
#   |               \-|-- /- /-them
#   |                 |
#   |                 |   /- /-if
#   |                  \-|
#   |                     \- /- /- /-necessary
#   |
#    \- /-.
#
# Relation: 899,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0275,	Type: Explicit,	Sense: Expansion.Conjunction,
# Arg1_sent_id: 10	,	Arg2_sent_id: 10
#
#       /- /- /-Does
#      |
#      |   /- /-this
#      |--|
#    /-|   \- /-team
#   |  |
#   |  |   /- /-have
#   |  |  |
#   |  |  |      /- /-a
#   |   \-|     |
#   |     |   /-|-- /-viable
#   |     |  |  |
#   |      \-|   \- /-strategy
#   |        |
#   |        |   /- /-for
#   |         \-|
#   |           |      /- /-improving
#   |            \- /-|
#   |                 |   /- /-shareholder
# --|                  \-|
#   |                     \- /-values
#   |
#   |-- /-*COMMA*
#   |
#   |-- /-and
#   |
#   |   /- /-does
#   |  |
#   |  |   /- /-this
#   |  |--|
#   |  |   \- /-strategy
#   |  |
#   |  |   /- /-require
#   |  |  |
#   |  |--|   /- /- /-implementation
#    \-|  |  |
#      |   \-|   /- /-over
#      |     |  |
#      |      \-|   /- /-an
#      |        |  |
#      |         \-|-- /-extended
#      |           |
#      |            \- /-period
#      |
#       \- /-?
#
# Relation: 966,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0278,	Type: Explicit,	Sense: Expansion.Conjunction,
# Arg1_sent_id: 7	,	Arg2_sent_id: 7
# None
# 0.08888888888888889

# %%
print(pdtb3.get_highlighted_parsetree(975, v=True))
# Out:
# Relation: 975,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0730,	Type: Explicit,	Sense: Contingency.Cause.Reason,
# Arg1_sent_id: 37	,	Arg2_sent_id: 37
# None

# %%
pdtb3.parse_data[106]
# Out:
# {'DocID': 'wsj_0799',
#  'ID': 106,
#  'Type': 'Explicit',
#  'Sense': ['Expansion.Conjunction'],
#  'Connective': {'CharacterSpanList': [[5809, 5817], [5878, 5886]],
#   'RawText': 'not only but also',
#   'TokenList': [[5809, 5812, 1089, 46, 2],
#    [5813, 5817, 1090, 46, 3],
#    [5878, 5881, 1097, 46, 10],
#    [5882, 5886, 1098, 46, 11]]},
#  'Arg1': {'CharacterSpanList': [[5818, 5876]],
#   'RawText': 'merged three military-electronics manufacturing operations',
#   'TokenList': [[5818, 5824, 1091, 46, 4],
#    [5825, 5830, 1092, 46, 5],
#    [5831, 5851, 1093, 46, 6],
#    [5852, 5865, 1094, 46, 7],
#    [5866, 5876, 1095, 46, 8]]},
#  'Arg2': {'CharacterSpanList': [[5887, 5976]],
#   'RawText': 'closed an unrelated plant that makes ordnance devices used in fighter planes and missiles',
#   'TokenList': [[5887, 5893, 1099, 46, 12],
#    [5894, 5896, 1100, 46, 13],
#    [5897, 5906, 1101, 46, 14],
#    [5907, 5912, 1102, 46, 15],
#    [5913, 5917, 1103, 46, 16],
#    [5918, 5923, 1104, 46, 17],
#    [5924, 5932, 1105, 46, 18],
#    [5933, 5940, 1106, 46, 19],
#    [5941, 5945, 1107, 46, 20],
#    [5946, 5948, 1108, 46, 21],
#    [5949, 5956, 1109, 46, 22],
#    [5957, 5963, 1110, 46, 23],
#    [5964, 5967, 1111, 46, 24],
#    [5968, 5976, 1112, 46, 25]]}}

# %%
# only for one individual sentence for implicit
# for PS case for explicit
# for PS case for implicit

# %%
for i, r in enumerate(pdtb3.parse_data):
    if r['Type'] != 'Explicit':
        continue
    if len(r['Connective']['TokenList']) > 2:
        print(r)
        print(i)
        break
# Out:
# {'DocID': 'wsj_0799', 'ID': 106, 'Type': 'Explicit', 'Sense': ['Expansion.Conjunction'], 'Connective': {'CharacterSpanList': [[5809, 5817], [5878, 5886]], 'RawText': 'not only but also', 'TokenList': [[5809, 5812, 1089, 46, 2], [5813, 5817, 1090, 46, 3], [5878, 5881, 1097, 46, 10], [5882, 5886, 1098, 46, 11]]}, 'Arg1': {'CharacterSpanList': [[5818, 5876]], 'RawText': 'merged three military-electronics manufacturing operations', 'TokenList': [[5818, 5824, 1091, 46, 4], [5825, 5830, 1092, 46, 5], [5831, 5851, 1093, 46, 6], [5852, 5865, 1094, 46, 7], [5866, 5876, 1095, 46, 8]]}, 'Arg2': {'CharacterSpanList': [[5887, 5976]], 'RawText': 'closed an unrelated plant that makes ordnance devices used in fighter planes and missiles', 'TokenList': [[5887, 5893, 1099, 46, 12], [5894, 5896, 1100, 46, 13], [5897, 5906, 1101, 46, 14], [5907, 5912, 1102, 46, 15], [5913, 5917, 1103, 46, 16], [5918, 5923, 1104, 46, 17], [5924, 5932, 1105, 46, 18], [5933, 5940, 1106, 46, 19], [5941, 5945, 1107, 46, 20], [5946, 5948, 1108, 46, 21], [5949, 5956, 1109, 46, 22], [5957, 5963, 1110, 46, 23], [5964, 5967, 1111, 46, 24], [5968, 5976, 1112, 46, 25]]}}
# 106

# %%
import itertools

stuff = [1, 2, 3]
for L in range(0, len(stuff)+1):
    for subset in itertools.combinations(stuff, 1):
        print(subset)
# Out:
# (1,)
# (2,)
# (3,)
# (1,)
# (2,)
# (3,)
# (1,)
# (2,)
# (3,)
# (1,)
# (2,)
# (3,)

# %%
import sys
sys.path.append('..')
from api.api import PDTB
import re
from ete3 import Tree
from collections import Counter

# %%
# pdtb2 = PDTB('/home/pengfei/data/pdtb_v2/all/conll/')
pdtb3 = PDTB('/home/pengfei/data/pdtb3/all/conll/')

# %% [markdown]
# ## previous sentence; Explicit

# %%
start, end = 0, 100

# %%
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0]-1 and pdtb3.parse_data[i]['Type'] == 'Explicit':
        pdtb3.get_simplified_parse_tree(i, 3, p=True, v=True)
# Out:
# Relation: 1,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0793,	Type: Explicit,	Sense: Expansion.Substitution.Arg2-as-subst,
# Arg1_sent_id: 1	,	Arg2_sent_id: 2
#
#
#    /-Arg1
# -S|
#    \-none
#
#    /-Conn
#   |
#   |--none
# -S|
#   |--Arg2
#   |
#    \-none
# Relation: 7,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0793,	Type: Explicit,	Sense: Comparison.Concession.Arg2-as-denier,
# Arg1_sent_id: 6	,	Arg2_sent_id: 7
#
#
#    /-Arg1
# -S|
#    \-none
#
#    /-Conn
#   |
#   |--none
# -S|
#   |--Arg2
#   |
#    \-none
# Relation: 23,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0739,	Type: Explicit,	Sense: Comparison.Concession.Arg2-as-denier,
# Arg1_sent_id: 4	,	Arg2_sent_id: 5
#
#
#    /-Arg1
# -S|
#    \-none
#
#    /-Arg2
#   |
#   |--none
#   |
#   |--Conn
# -S|
#   |--none
#   |
#   |--Arg2
#   |
#    \-none
# ...

# %%
start, end = 100, 200
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0]-1 and pdtb3.parse_data[i]['Type'] == 'Explicit':
        pdtb3.get_simplified_parse_tree(i, 3, p=True, v=True)
# Out:
# Relation: 109,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0799,	Type: Explicit,	Sense: Comparison.Concession.Arg2-as-denier,
# Arg1_sent_id: 49	,	Arg2_sent_id: 50
#
#
#    /``/-``
#   |
#   |-NP/PRP-I
#   |
#   |   /MD/-would
#   |  |
#   |-VP-RB/-n't
#   |  |
#   |  |   /VB/-say
#   |   \VP
#   |     |       /NP/PRP-we
# -S|      \SBARS|
#   |            |   /VBP-'re
#   |             \VP
#   |               |   /IN/-out
#   |                \PP
#   |                  |   /IN/-of
#   |                   \PP
#   |                     |   /DT/-the
#   |                      \NP
#   |                         \NN/-business
#   |
#    \. /-.
#
#
#
#
#    /CC/-But
#   |
#   |-NP/PRP-we
#   |
#   |   /VBP-'re
#   |  |
#   |  |-RB/-not
#   |  |
#   |-VP   /VBG-making
#   |  |  |
#   |  |  |        /RB/-as
#   |  |  |    /ADJP
#   |   \VP   |    \JJ/-many
#   |     |   |
#   |     |   |   /-LRB---LCB-
# -S|     |   |  |
#   |     |   |  |   /JJ/-pyrotechnic
# ...

# %%
start, end = 200, 300
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0]-1 and pdtb3.parse_data[i]['Type'] == 'Explicit':
        pdtb3.get_simplified_parse_tree(i, 3, p=True, v=True)
# Out:
# Relation: 200,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0732,	Type: Explicit,	Sense: Comparison.Concession.Arg2-as-denier,
# Arg1_sent_id: 7	,	Arg2_sent_id: 8
#
#
#    /CC/-But
#   |
#   |   /IN/-in
#   |-PP
#   |  |   /DT/-any
#   |   \NP
#   |      \NN/-event
#   |
#   |   /*COLON*---
#   |  |
#   |  |-CC/-and
#   |  |
#   |  |   /NP/DT/-this
#   |  |  |
#   |  |-S|   /VBZ-is
#   |-PRN |  |
#   |  |   \VP   /DT/-the
#   |  |     |  |
#   |  |      \NP-JJ/-important
#   |  |        |
#   |  |         \NN/-point
#   |  |
#   |   \*COLON*---
#   |
#   |      /NN/-tax
#   |     |
#   |     |-``/-``
#   |   /NP
#   |  |  |-NNS-payments
#   |  |  |
#   |-NP   \''/-''
#   |  |
#   |  |   /IN/-on
#   |   \PP
#   |     |   /NN/-capital
#   |      \NP
#   |         \NNS-gains
#   |
#   |   /MD/-will
#   |  |
#   |  |   /VB/-be
#   |  |  |
# -S|  |  |    /ADJPJJR-lower
#   |  |  |   |
#   |  |  |   |   /IN/-with
#   |-VP  |-ADJPPP
# ...

# %%
start, end = 300, 400
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0]-1 and pdtb3.parse_data[i]['Type'] == 'Explicit':
        pdtb3.get_simplified_parse_tree(i, 3, p=True, v=True)
# Out:
# Relation: 300,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0766,	Type: Explicit,	Sense: Expansion.Instantiation.Arg2-as-instance,
# Arg1_sent_id: 39	,	Arg2_sent_id: 40
#
#
#       /IN/-For
#    /PP
#   |   \NP/NN/-example
#   |
#   |-*COMMA*-*COMMA*
#   |
#   |   /NP/NNS-officials
#   |  |
#   |-NP   /IN/-at
#   |  |  |
#   |   \PP   /NNP-Walnut
#   |     |  |
#   |      \NP-NNP-Creek
#   |        |
#   |         \NN/-office
#   |
#   |   /VBD-learned
#   |  |
#   |  |    /IN/-that
#   |  |   |
#   |  |   |         /DT/-the
#   |  |   |        |
#   |  |   |      /NP-NNP-Amfac
#   |-VP   |     |  |
#   |  |   |     |   \NNP-Hotel
#   |  |   |     |
#   |  |   |     |   /IN/-near
#   |  |   |     |  |
#   |  |   |     |-PP   /DT/-the
#   |  |   |     |  |  |
#   |   \SBAR    |  |  |-NNP-San
#   |      |     |   \NP
#   |      |     |     |-NNP-Francisco
#   |      |     |     |
#   |      |     |      \NN/-airport
#   |      |   /NP
# ...

# %% [markdown]
# ## previous sentence; Implicit

# %%
start, end = 0, 100
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0]-1 and pdtb3.parse_data[i]['Type'] == 'Implicit':
        pdtb3.print_highlighted_parsetree(i, v=True)
# Out:
# Relation: 2,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0793,	Type: Implicit,	Sense: Temporal.Asynchronous.Precedence,
# Arg1_sent_id: 2	,	Arg2_sent_id: 3
#
#
#    /ADVPRB/-Instead
#   |
#   |-*COMMA*-*COMMA*
#   |
#   |         /NNP-Congress
#   |      /NP
#   |   /NP   \POS-'s
#   |  |  |
#   |-NP   \NN/-idea
#   |  |
#   |  |   /IN/-of
#   |   \PP
#   |      \NP/NN/-reform
#   |
#   |   /VBZ-is
#   |  |
#   |-VP      /TO/-to
# -S|  |     |
#   |  |     |   /VB/-increase
#   |   \S /VP  |
#   |        |  |   /DT/-this
#   |        |  |  |
#   |        |  |-NP-JJ/-slush
#   |         \VP  |
#   |           |   \NN/-fund
#   |           |
#   |           |   /IN/-by
#   |           |  |
#   |            \PP      /$ /-$
#   |              |     |
#   |               \NP/QP-CD/-28.4
#   |                    |
#   |                     \CD/-million
#   |
#    \. /-.
#
#
#
#
#    /CC/-And
#   |
#   |   /VB/-transfer
#   |  |
#   |  |   /NP/NN/-control
# ...

# %%
start, end = 100, 200
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0]-1 and pdtb3.parse_data[i]['Type'] == 'Implicit':
        pdtb3.print_highlighted_parsetree(i, v=True)
# Out:
# Relation: 104,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0799,	Type: Implicit,	Sense: Contingency.Cause.Reason,
# Arg1_sent_id: 43	,	Arg2_sent_id: 44
#
#
#        /NP/NNS-Telos
#       |
#     /S|   /VBD-responded
#    |  |  |
#    |   \VP   /IN/-by
#    |     |  |
#    |     |  |      /VBG-combining
#    |      \PP     |
#    |        |     |      /NP/CD/-three
#    |        |     |     |
#    |        |     |   /NP   /IN/-of
#    |         \S /VP  |  |  |
#    |              |  |   \PP   /PRP$-its
#    |              |  |     |  |
#    |              |  |      \NP-CD/-five
#    |              |  |        |
#    |               \S|         \NNS-divisions
#    |                 |
#    |                 |   /TO/-to
#    |                 |  |
#    |                 |  |      /VB/-reduce
#    |                 |  |   /VP
#    |                  \VP  |   \NP/NNS-expenses
#    |                    |  |
#    |                    |  |-CC/-and
# ...

# %% [markdown]
# ## same sentence; Explicit

# %%
start, end = 0, 100
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0] and pdtb3.parse_data[i]['Type'] == 'Explicit':
        pdtb3.print_highlighted_parsetree(i, v=True)
# Out:
# Relation: 6,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0793,	Type: Explicit,	Sense: Expansion.Conjunction,
# Arg1_sent_id: 6	,	Arg2_sent_id: 6
#
#
#       /NP/NNP-HUD
#      |
#    /S|   /VBZ-has
#   |  |  |
#   |  |  |      /DT/-no
#   |   \VP     |
#   |     |   /NP-NN/-paper
#   |     |  |  |
#   |     |  |   \NN/-work
#   |      \NP
#   |        |-ADVPRB/-whatsoever
#   |        |
#   |        |   /IN/-on
#   |         \PP
#   |           |   /NP/CD/-30
#   |            \NP
#   |              |   /IN/-of
#   |               \PP
#   |                 |   /DT/-the
#   |                  \NP
#   |                     \NNS-projects
#   |
#   |-*COMMA*-*COMMA*
#   |
#   |      /NP/NN/-none
#   |   /NP
#   |  |  |   /IN/-of
#   |  |   \PP
#   |  |     |   /DT/-the
#   |-S|      \NP
#   |  |         \NNS-others
#   |  |
#   |  |   /VBZ-has
# -S|   \VP
#   |     |   /VBN-been
#   |      \VP
#   |         \VP/VBN-approved
#   |
#   |-CC/-and
#   |
# ...

# %%
start, end = 100, 200
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0] and pdtb3.parse_data[i]['Type'] == 'Explicit':
        pdtb3.print_highlighted_parsetree(i, v=True)
# Out:
# Relation: 102,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0799,	Type: Explicit,	Sense: Comparison.Concession.Arg2-as-denier,
# Arg1_sent_id: 42	,	Arg2_sent_id: 42
#
#
#          /DT/-A
#         |
#       /NP-JJ/-one-time
#      |  |
#    /NP   \NN/-write-off
#   |  |
#   |  |   /IN/-for
#   |   \PP
#   |     |      /VBG-booking
#   |      \S /VP
#   |           |   /JJ/-nonexistent
#   |            \NP
#   |               \NN/-revenue
#   |
#   |      /VBD-was
#   |     |
#   |   /VP-ADVPRB/-partly
#   |  |  |
#   |  |  |      /TO/-to
#   |  |   \S /VP
#   |  |         \VP/VB/-blame
#   |  |
#   |  |-*COMMA*-*COMMA*
#   |-VP
#   |  |-CC/-but
#   |  |
#   |  |-RB/-so
#   |  |
#   |  |   /VBD-were
#   |  |  |
#   |  |  |      /JJR-lower
# -S|   \VP   /NP
#   |     |  |   \NNS-profits
#   |     |  |
#   |     |  |   /IN/-from
#   |      \NP  |
#   |        |  |         /DT/-a
#   |        |  |        |
#   |        |  |      /NP-JJR-stingier
# ...

# %% [markdown]
# ## same sentence; Implicit

# %%
start, end = 0, 100
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0] and pdtb3.parse_data[i]['Type'] == 'Implicit':
        pdtb3.print_highlighted_parsetree(i, v=True)
# Out:
# Relation: 5,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0793,	Type: Implicit,	Sense: Expansion.Conjunction,
# Arg1_sent_id: 6	,	Arg2_sent_id: 6
#
#
#       /NP/NNP-HUD
#      |
#    /S|   /VBZ-has
#   |  |  |
#   |  |  |      /DT/-no
#   |   \VP     |
#   |     |   /NP-NN/-paper
#   |     |  |  |
#   |     |  |   \NN/-work
#   |      \NP
#   |        |-ADVPRB/-whatsoever
#   |        |
#   |        |   /IN/-on
#   |         \PP
#   |           |   /NP/CD/-30
#   |            \NP
#   |              |   /IN/-of
#   |               \PP
#   |                 |   /DT/-the
#   |                  \NP
#   |                     \NNS-projects
#   |
#   |-*COMMA*-*COMMA*
#   |
#   |      /NP/NN/-none
#   |   /NP
#   |  |  |   /IN/-of
#   |  |   \PP
#   |  |     |   /DT/-the
#   |-S|      \NP
#   |  |         \NNS-others
#   |  |
#   |  |   /VBZ-has
# -S|   \VP
#   |     |   /VBN-been
#   |      \VP
#   |         \VP/VBN-approved
#   |
#   |-CC/-and
#   |
# ...

# %%
start, end = 100, 200
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0] and pdtb3.parse_data[i]['Type'] == 'Implicit':
        pdtb3.print_highlighted_parsetree(i, v=True)
# Out:
# Relation: 128,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0781,	Type: Implicit,	Sense: Expansion.Level-of-detail.Arg2-as-detail,
# Arg1_sent_id: 12	,	Arg2_sent_id: 12
#
#
#    /NP/NN/-Yesterday
#   |
#   |-*COMMA*-*COMMA*
#   |
#   |-NP/NNP-Compaq
#   |
#   |   /VBD-plunged
#   |  |
#   |  |-ADVPRB/-further
#   |  |
#   |  |-*COMMA*-*COMMA*
#   |  |
#   |  |      /VBG-closing
#   |  |     |
#   |  |-S /VP   /IN/-at
#   |  |     |  |
#   |  |      \PP      /$ /-$
#   |  |        |   /NP
#   |  |        |  |   \CD/-100
#   |  |         \NP
#   |  |           |   /DT/-a
#   |  |            \NP
#   |-VP               \NN/-share
#   |  |
# -S|  |-*COMMA*-*COMMA*
#   |  |
#   |  |    /RB/-off
#   |  |   |
#   |  |-ADVP     /$ /-$
#   |  |   |   /NP
#   |  |   |  |   \CD/-8.625
#   |  |    \NP
#   |  |      |   /DT/-a
#   |  |       \NP
#   |  |          \NN/-share
#   |  |
#   |  |-*COMMA*-*COMMA*
#   |  |
#   |  |   /IN/-on
#   |   \PP
# ...

# %%
start, end = 200, 300
for i in range(start, end):
    if pdtb3.get_arg_sent_id(i, 'Arg1')[0] == pdtb3.get_arg_sent_id(i, 'Arg2')[0] and pdtb3.parse_data[i]['Type'] == 'Implicit':
        pdtb3.print_highlighted_parsetree(i, v=True)
# Out:
# Relation: 205,  Green for Connective(if any), Red for Arg1 and Blue for Arg2.
# DocID: wsj_0732,	Type: Implicit,	Sense: Contingency.Cause.Result,
# Arg1_sent_id: 13	,	Arg2_sent_id: 13
#
#
#       /DT/-The
#    /NP
#   |   \NN/-reduction
#   |
#   |      /VBZ-eases
#   |     |
#   |     |   /DT/-the
#   |   /VP-NP
#   |  |  |   \NN/-burden
#   |  |  |
#   |  |  |   /IN/-on
#   |  |   \PP
#   |  |     |   /NN/-portfolio
#   |  |      \NP
#   |-VP         \NNS-changes
#   |  |
#   |  |-CC/-and
#   |  |
#   |  |   /VBZ-frees
# -S|  |  |
#   |  |  |-NP/NN/-capital
#   |   \VP
#   |     |      /TO/-to
#   |     |     |
#   |     |     |   /VB/-seek
#   |      \S /VP  |
#   |           |  |           /RBR-more
#   |           |  |       /ADJP
#   |            \VP      |    \JJ/-productive
#   |              |      |
#   |              |   /ADJPCC/-or
#   |              |  |   |
#   |              |  |   |    /RBR-more
#   |               \NP    \ADJP
# ...

# %%
rules = []
for i in range(len(pdtb3.parse_data)):
    syntax_trees = pdtb3.get_highlighted_parsetree(i)
    for s in syntax_trees:
        simplified_tree = simplify_tree(s.tree)
        s.tree = more_simplify_tree(s.tree)
        s.tree = most_simplify_tree(s.tree)
        rules = get_tree_rules(s.tree, rules)
# Out:
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# Parse tree is not generated
# ...

# %%
wordlize = list( map(lambda x: x[0]+':'+' '.join(x[1]), rules) )

# %%
len(set(wordlize)), len(wordlize)
# Out:
# (1864, 111107)

# %%
counter = Counter(wordlize)
counter.most_common()
# Out:
# [('S:Arg1 none', 17670),
#  ('S:Arg2 none', 14310),
#  ('S:none VP none', 10681),
#  ('SBAR:Conn Arg2', 4422),
#  ('S:Arg1 VP none', 3354),
#  ('VP:none Arg1', 3154),
#  ('VP:none VP', 2266),
#  ('VP:none S', 2110),
#  ('S:Conn Arg2 none', 1853),
#  ('VP:none Arg2', 1804),
#  ('S:none Arg1 none', 1656),
#  ('S:none Arg2 none', 1487),
#  ('VP:Arg1 SBAR', 1437),
#  ('VP:Arg1 Conn Arg2', 1219),
#  ('S:Conn none Arg2 none', 1153),
#  ('S:Arg1 none Conn Arg2 none', 1072),
#  ('VP:Arg1 none Arg2', 951),
#  ('NP:Arg1 none', 942),
#  ('VP:Arg1 Arg2', 935),
#  ('PP:Conn Arg2', 935),
#  ('S:SBAR none Arg1 none', 906),
#  ('S:none NP none', 901),
#  ('S:none S none', 839),
#  ('NP:Arg2 none', 823),
#  ('SINV:none Arg1 none', 813),
#  ('VP:Arg1 none SBAR', 727),
#  ('VP:Arg2 none', 720),
#  ('S:Arg2 VP none', 715),
#  ('S:Arg2 Conn Arg2 none', 706),
#  ('S:none Arg1', 593),
#  ('S:none VP', 586),
#  ('VP:none SBAR', 535),
#  ('SINV:none Arg2 none', 528),
#  ('S:none SBAR none', 487),
# ...

# %%
new_rules = []
tags = ['Arg1', 'Arg2', 'Conn', 'S', 'none', 'tag']
for r in rules:
    parent = r[0]
    if parent not in tags:
        parent = 'tag'
    temp = []
    for c in r[1]:
        if c not in tags:
            temp.append('tag')
        else:
            temp.append(c)
    new_rules.append(parent + ': ' + ' '.join(temp))

# %%
len(set(new_rules)), len(new_rules)
# Out:
# (697, 111107)

# %%
count = 0
for o,v in dict(Counter(new_rules).most_common()).items():
    if v < 7:
        count += v

# %%
count
# Out:
# 823

# %%
# def simplify_tree(tree):
#     temp = []
#     if tree.name in ['Arg1', 'Arg2', 'none', 'Conn']:
#         return tree.name
#     for c in tree.children:
#         child_label = simplify_tree(c)
#         temp.append(child_label)
#     if len(set(temp)) == 1:
#         tree.name = temp[0]
#         tree.children = []
#     return tree.name

# def more_simplify_tree(tree):
#     temp = []
    
#     ## simplify among siblings
#     prev_c = None
#     for c in tree.children:
#         c = more_simplify_tree(c)
#         if c.name != prev_c:
#             temp.append(c)
#             prev_c = c.name
#     tree.children = temp
#     return tree

# def most_simplify_tree(tree):
#     for i, c in enumerate(tree.children):
#         tree.children[i] = most_simplify_tree(c)
#     if len(tree.children) == 2:
#         # for left branch
#         if len(tree.children[1].children) >= 1:
#             if tree.children[1].children[0].name == tree.children[0].name:
#                 tree = tree.children[1]
#         # for right branch
#         if len(tree.children[0].children) >= 1:
#             if tree.children[0].children[1].name == tree.children[1].name:
#                 tree = tree.children[0]
#     return tree


# def get_tree_rules(tree, rules):
#     for c in tree.children:
#         rules = get_tree_rules(c, rules)
#     children = list(map(lambda x:x.name, tree.children))
#     if children != []:
#         rules.append( (tree.name, children ) )
#     return rules
